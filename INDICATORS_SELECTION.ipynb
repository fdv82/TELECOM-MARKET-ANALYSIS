# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#SCM PODER DE COMPRA SALARIO MINIMO
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
#BASICA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[18,26,22,27,59,73]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax1.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax1.tick_params(axis='x', rotation=75)
ax1.set_xticklabels(df_sorted.pais, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax1.get_children()[pos[0]].set_color('r')
ax1.set_title("BASICO\n(cuota datos <= 6 GB)", fontweight="bold", y=1.05, fontsize=20)
#INTERMEDIA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[9,18,13,18,34,60]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax2.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax2.tick_params(axis='x', rotation=75)
ax2.set_xticklabels(df_sorted.pais, fontsize=20)
ax2.get_yaxis().set_visible(False)
ax2.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax2.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax2.get_children()[pos[0]].set_color('r')
ax2.set_title("INTERMEDIO\n(cuota datos entre 7 y 19 GB)", fontweight="bold", y=1.05, fontsize=20)
#AVANZADO
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "CHILE", "COLOMBIA", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[7,10,47,26,8,11,26,49]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax3.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax3.tick_params(axis='x', rotation=75)
ax3.set_xticklabels(df_sorted.pais, fontsize=20)
ax3.get_yaxis().set_visible(False)
ax3.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax3.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax3.get_children()[pos[0]].set_color('r')
ax3.set_title("AVANZADO\n(cuota datos >= 20 GB)", fontweight="bold", y=1.05, fontsize=20)

my_suptitle = fig.suptitle("CANTIDAD DE PLANES SCM ASEQUIBLES\nAL VALOR DE UN (1) SALARIO MINIMO", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-2-8d1f222865eb>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_sorted.pais, fontsize=20)
# <ipython-input-2-8d1f222865eb>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(df_sorted.pais, fontsize=20)
# <ipython-input-2-8d1f222865eb>:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(df_sorted.pais, fontsize=20)

# %%
# VALOR PLANES EN USD
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
#BASICA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[18,10,17,14,5,8]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax1.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax1.tick_params(axis='x', rotation=75)
ax1.set_xticklabels(df_sorted.pais, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax1.get_children()[pos[0]].set_color('r')
ax1.set_title("BASICO\n(cuota datos <= 6 GB)", fontweight="bold", y=1.05, fontsize=20)
#INTERMEDIA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[35,15,28,20,8,9]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax2.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax2.tick_params(axis='x', rotation=75)
ax2.set_xticklabels(df_sorted.pais, fontsize=20)
ax2.get_yaxis().set_visible(False)
ax2.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax2.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax2.get_children()[pos[0]].set_color('r')
ax2.set_title("INTERMEDIO\n(cuota datos entre 7 y 19 GB)", fontweight="bold", y=1.05, fontsize=20)
#AVANZADO
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "CHILE", "COLOMBIA", "MEXICO", "PARAGUAY", "PERU", "URUGUAY"],
      valor=[44,27,11,11,48,33,11,11]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax3.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax3.tick_params(axis='x', rotation=75)
ax3.set_xticklabels(df_sorted.pais, fontsize=20)
ax3.get_yaxis().set_visible(False)
ax3.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax3.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax3.get_children()[pos[0]].set_color('r')
ax3.set_title("AVANZADO\n(cuota datos >= 20 GB)", fontweight="bold", y=1.05, fontsize=20)

my_suptitle = fig.suptitle("VALOR DE LOS PLANES SCM EN USD", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-3-2561ed9ec128>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_sorted.pais, fontsize=20)
# <ipython-input-3-2561ed9ec128>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(df_sorted.pais, fontsize=20)
# <ipython-input-3-2561ed9ec128>:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(df_sorted.pais, fontsize=20)

# %%
#IF VALOR PLANES EN USD
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
#BASICA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "CHILE", "COLOMBIA", "MEXICO", "PERU"],
      valor=[7,26.4,2.1,7.6,22.5,1.8]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax1.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax1.tick_params(axis='x', rotation=75)
ax1.set_xticklabels(df_sorted.pais, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax1.get_children()[pos[0]].set_color('r')
ax1.set_title("CANTIDAD DE ABONADOS\n(en millones)", fontweight="bold", y=1.05, fontsize=20)

#INTERMEDIA
df = pd.DataFrame(
   dict(
      pais=["ARGENTINA", "BRASIL", "CHILE", "COLOMBIA", "MEXICO", "PERU"],
      valor=[3077,2374,2179,2784,3508,4465]
   )
)
df_sorted = df.sort_values('valor').reset_index(drop=True)
ax2.bar(df_sorted.pais, df_sorted.valor, data=df_sorted)
ax2.tick_params(axis='x', rotation=75)
ax2.set_xticklabels(df_sorted.pais, fontsize=20)
ax2.get_yaxis().set_visible(False)
ax2.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df_sorted.valor):
    ax2.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
#color ARGENTINA
pos=df_sorted[df_sorted["pais"]=="ARGENTINA"].index.values
ax2.get_children()[pos[0]].set_color('r')
ax2.set_title("VALOR INDICE HHI", fontweight="bold", y=1.05, fontsize=20)
#linea horizontal
ax2.axhline(y = 2500, color = 'black', linestyle = ':', label = "Cota máxima: 2500")
ax2.axhline(y = 1500, color = 'black', linestyle = '--', label = "Cota mínima: 1500")
ax2.legend(fontsize=16)

my_suptitle = fig.suptitle("SERVICIO DE TELEFONIA FIJA", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

ax1.text(-1,6, "Fuente: Elaboración propia en\nbase a organismos reguladores", fontsize=12,rotation=90,ha = 'center')

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-4-1b8f90f7fcf7>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_sorted.pais, fontsize=20)
# <ipython-input-4-1b8f90f7fcf7>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(df_sorted.pais, fontsize=20)

# %%
#IF VALOR PLANES EN USD
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(2,3,1)
ax2 = fig.add_subplot(2,3,2)
ax3 = fig.add_subplot(2,3,3)
ax4 = fig.add_subplot(2,3,4)
ax5 = fig.add_subplot(2,3,5)
ax6 = fig.add_subplot(2,3,6)

#ARGENTINA
labels = 'TELECOM', 'TELEFONICA\n(MOVISTAR)', 'TELECENTRO', 'OTROS'
sizes = [42, 30, 21, 7]
ax1.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=[ '#099BFF','#20FF09', 'ORANGE', '#E809FF'], textprops={'fontsize': 14})
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
ax1.set_title("ARGENTINA", fontweight="bold", fontsize=20)

#BRASIL
labels = 'AMERICA MOVIL\n(CLARO)', 'TELEFONICA\n(VIVO)', 'OI','OTROS'
sizes = [29, 26, 28, 17]
ax2.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=[ 'red','#20FF09', '#099BFF', '#E809FF'], textprops={'fontsize': 14})
ax2.get_yaxis().set_visible(False)
ax2.set(frame_on=False)
ax2.set_title("BRASIL", fontweight="bold", fontsize=20)

#CHILE
labels = 'AMERICA MOVIL\n(CLARO)', 'TELEFONICA\n(MOVISTAR)', 'VTR',"ENTEL",'OTROS'
sizes = [5, 35, 21, 19, 20]
ax3.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=['red','#20FF09', 'ORANGE', "#099BFF", '#E809FF'], textprops={'fontsize': 14})
ax3.get_yaxis().set_visible(False)
ax3.set(frame_on=False)
ax3.set_title("CHILE", fontweight="bold", fontsize=20)

#COLOMBIA
labels = 'AMERICA MOVIL\n(CLARO)', 'TELEFONICA\n(MOVISTAR)', 'MILLICOM\n(TIGO)',"ETB",'OTROS'
sizes = [43, 18, 22, 12, 5]
ax4.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=[ 'red','#20FF09', 'ORANGE', "#099BFF", '#E809FF'], textprops={'fontsize': 14})
ax4.get_yaxis().set_visible(False)
ax4.set(frame_on=False)
ax4.set_title("COLOMBIA", fontweight="bold", fontsize=20)
#MEXICO
labels = 'AMERICA MOVIL\n(TELMEX)', 'TELEVISA', 'MEGACABLE', 'OTROS'
sizes = [45, 33, 19, 3]
ax5.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=[ 'red','ORANGE', "#099BFF", '#E809FF'], textprops={'fontsize': 14})
ax5.get_yaxis().set_visible(False)
ax5.set(frame_on=False)
ax5.set_title("MEXICO", fontweight="bold", fontsize=20)
#PERU
labels = 'AMERICA MOVIL\n(CLARO)', 'TELEFONICA\n(MOVISTAR)', 'ENTEL','OTROS'
sizes = [33, 58, 2, 7]
ax6.pie(sizes,labels=labels,autopct='%1.0f%%',
        shadow=True, startangle=90, colors=[ 'red','#20FF09', '#099BFF', '#E809FF'], textprops={'fontsize': 14})
ax6.get_yaxis().set_visible(False)
ax6.set(frame_on=False)
ax6.set_title("PERU", fontweight="bold", fontsize=20)

my_suptitle = fig.suptitle("CUOTAS DE MERCADO TELEFONIA FIJA\n(Fuente: elaboración propia en base a organismos reguladores)", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()

# %%
df = pd.DataFrame(
   dict(
      Año=["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023"],
      Susc=[22,30,41,54,71,89,111,139,167,204,222,231,238]
   )
)
#grafico
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,1,1)
ax1.bar(df.Año, df.Susc)
ax1.tick_params(axis='x', rotation=75)
ax1.set_xticklabels(df.Año, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df.Susc):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)

ax1.text(11,-55, "Fuente: STATISTA y SEC", fontsize=12, ha = 'center')

my_suptitle = fig.suptitle("CANTIDAD DE SUSCRIPTORES DE NETFLIX\n(nivel mundial, en millones)", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-6-74151808db37>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df.Año, fontsize=20)

# %%
#SCM ARGENTINA/PROMEDIO
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,1,1)

#SALARIO MINIMO

X = ['TELEFONIA FIJA','TV PAGA','SCM', "INTERNET FIJA"]
ARG = [3077,1549,3492,1770]
PRO = [3065,3074,3354,2402]


X_axis = np.arange(len(X))

ax1.bar(X_axis - 0.2, ARG, 0.4, label = 'ARGENTINA', color = 'r')
ax1.bar(X_axis + 0.2, PRO, 0.4, label = 'PROMEDIO\nREGIONAL')

ax1.tick_params(axis='x', rotation=75)
X.insert(0, "BASICO")
ax1.set_xticklabels(X, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax1.set(frame_on=False)
#ax1.set_title("CANTIDAD PLANES SCM\nASEQUIBLES AL VALOR\nDE UN (1) SALARIO MINIMO", fontweight="bold", y=1.05, fontsize=20)
#agrega etiquetas de valor
for i, value in enumerate(ARG):
    ax1.text(i, value, str(value), ha='right', va='center', fontsize=22)
for i, value in enumerate(PRO):
    ax1.text(i, value, str(value), ha='left', va='center', fontsize=22)

#linea horizontal
ax1.axhline(y = 2500, color = 'black', linestyle = ':', label = "Cota máxima: 2500")
ax1.axhline(y = 1500, color = 'black', linestyle = '--', label = "Cota mínima: 1500")
ax1.legend(fontsize=16)

#etiquetas x
ax1.text(0,-1, "TELEFONIA FIJA", fontsize=20, ha = 'center')
ax1.text(1,-1, "TV PAGA", fontsize=20, ha = 'center')
ax1.text(2,-1, "SCM", fontsize=20, ha = 'center')
ax1.text(3,-1, "INTERNET FIJA", fontsize=20, ha = 'center')

ax1.text(-1,800, "NO\nCONCENTRADO", fontsize=20, ha = 'center')
ax1.text(-1,1800, "MODERADAMENTE\nCONCENTRADO", fontsize=20, ha = 'center')
ax1.text(-1,2700, "ALTAMENTE\nCONCENTRADO", fontsize=20, ha = 'center')

ax1.text(2.5,-115, "Fuente: Elaboración propia en base a organismos reguladores", fontsize=12, ha = 'center')

my_suptitle = fig.suptitle("COMPARACION INDICADOR HHI\nARGENTINA vs PROMEDIO REGIONAL", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-7-cf9ebf888ac9>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(X, fontsize=20)

# %%
#SCM ARGENTINA/PROMEDIO
#GRAFICO
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,1,1)

#SALARIO MINIMO

X = ['SCM', "INTERNET FIJA"]
ARG = [3492,1770]
PRO = [3354,2402]


X_axis = np.arange(len(X))

ax1.bar(X_axis - 0.1, ARG, 0.3, label = 'ARGENTINA', color = '#7FFFD4')
ax1.bar(X_axis+0.1, PRO, 0.3, label = 'PROMEDIO\nREGIONAL')

ax1.tick_params(axis='x', rotation=75)
#X.insert(0, "BASICO")
ax1.set_xticklabels(X, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax1.set(frame_on=False)
#ax1.set_title("CANTIDAD PLANES SCM\nASEQUIBLES AL VALOR\nDE UN (1) SALARIO MINIMO", fontweight="bold", y=1.05, fontsize=20)
#agrega etiquetas de valor
for i, value in enumerate(ARG):
    ax1.text(i, value, str(value), ha='right', va='center', fontsize=22)
for i, value in enumerate(PRO):
    ax1.text(i, value, str(value), ha='left', va='center', fontsize=22)

#linea horizontal
ax1.axhline(y = 2500, color = 'black', linestyle = ':', label = "Cota máxima: 2500")
ax1.axhline(y = 1500, color = 'black', linestyle = '--', label = "Cota mínima: 1500")
ax1.legend(fontsize=16)

#etiquetas x
#ax1.text(0,-1, "TELEFONIA FIJA", fontsize=20, ha = 'center')
#ax1.text(1,-1, "TV PAGA", fontsize=20, ha = 'center')
ax1.text(0,-1, "SCM", fontsize=20, ha = 'center')
ax1.text(1,-1, "INTERNET FIJA", fontsize=20, ha = 'center')

ax1.text(-1,800, "NO\nCONCENTRADO", fontsize=20, ha = 'center')
ax1.text(-1,1800, "MODERADAMENTE\nCONCENTRADO", fontsize=20, ha = 'center')
ax1.text(-1,2700, "ALTAMENTE\nCONCENTRADO", fontsize=20, ha = 'center')

ax1.text(0,-300, "Fuente: Elaboración propia en base a organismos reguladores", fontsize=12, ha = 'center')

my_suptitle = fig.suptitle("COMPARACION INDICADOR HHI\nARGENTINA vs PROMEDIO REGIONAL", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-8-3c553dc9cdaa>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(X, fontsize=20)

# %%
import urllib
from PIL import Image
fake_data = {
    "":["Uruguay","Peru","Paraguay","Mexico", "Colombia","Chile", "Brasil", "Argentina"],
    "SALARIO MINIMO\n(en moneda local)":["$21.106","$1.025","$2.680.373", "$6.310", "$1.160.000", "$440.000","$1.320","$112.500"],
    "TIPO DE CAMBIO USD":["$38,29" ,           "$3,7","$7.275,37","$16,79" , "$4.065,5" ,"$855,18","$4,86", "$349,97"],
  }

df_working = pd.DataFrame(fake_data)
def ax_logo(country, ax):
    '''
    Plots the logo of the team at a specific axes.
    Args:
        team_id (int): the id of the team according to Fotmob. You can find it in the url of the team page.
        ax (object): the matplotlib axes where we'll draw the image.
    '''
    if country == "Brasil":
        country= "Brazil"

    logo_url = f'https://img.icons8.com/color/344/{country.lower()}-circular.png'
    logo = Image.open(urllib.request.urlopen(logo_url))
    ax.imshow(logo)
    ax.axis('off')
    return ax
# making the structure
#fig, ax = plt.subplots(figsize=(14,8), dpi=300)
fig, ax = plt.subplots(figsize=(13.33,7.5), dpi=96)
rows = 9 #   number of rows that we want
cols = 3 #   number of columns that we want


ax.set_ylim(-.5, rows) #  y limits
ax.set_xlim(0, cols) #  X limits

# iterating over each row of the dataframe and plot the text
# df_working is a DataFrame object with our fake data
for row in df_working.iterrows(): # this will return the row as a tupple

        # row[0] will be the index of the row
        # row[1] will be the actual data as a Series

        # ploting the country
        ax.text(x=.5, y=row[0], s=row[1][""], va="center", ha="left", weight="bold", size=20)

        # 1979
        ax.text(x=1.75, y=row[0], s=row[1]["SALARIO MINIMO\n(en moneda local)"], va="center", ha="center", size=20)

        # 2017
        ax.text(x=2.5, y=row[0], s=row[1]["TIPO DE CAMBIO USD"], va="center", ha="center", size=20)

        # %
        #ax.text(x=3.25, y=row[0], s=row[1]["%"], va="center", ha="center", size=14)




ax.axis('off') # removing all the spines

# Adding the headers
ax.text(1.75, rows-1, "SALARIO MINIMO\n(moneda local)", weight='bold', ha='center', size=18)
ax.text(2.5, rows-1, 'TIPO DE CAMBIO\n(usd-moneda local)', weight='bold', ha='center', size=18)
#ax.text(3.25, rows-1, '%', weight='bold', ha='center', size=16)

# Adding title
ax.set_title(
        'INDICADORES ECONOMICOS UTILIZADOS EN EL ANALISIS',
        loc='center',
        fontsize=24,
        weight='bold'
    )

# adds main line belowthe headers
ax.plot([.25,cols-.2], [rows-1.2, rows-1.2],ls="-",lw=1,c="black")


# adds multiple lines below each row
for row in df_working.iterrows():
        ax.plot(
            [.25, cols-.2],
            [row[0] -.5, row[0] - .5],
            ls=':',
            lw='.5',
            c='grey'
        )




# -- Transformation functions
DC_to_FC = ax.transData.transform
FC_to_NFC = fig.transFigure.inverted().transform


# -- Take data coordinates and transform them to normalized figure coordinates
DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))

# -- Add nation axes
ax_point_1 = DC_to_NFC([2.25, 0.25])
ax_point_2 = DC_to_NFC([2.75, 0.75])


ax_width = abs(ax_point_1[0] - ax_point_2[0])
ax_height = abs(ax_point_1[1] - ax_point_2[1])

for x in range(0, rows-1):
    ax_coords = DC_to_NFC([.8, x-.25])
    flag_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_width, ax_height]
    )
    ax_logo(df_working[''].iloc[x], flag_ax)

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()

# %%
df = pd.DataFrame(
   dict(
      Año=["2014","2015","2016","2017","2018","2019","2020","2021","2022"],
      Susc=[100,93,85,85,76,64,62,59,46],tot=[100,99,92,97,89,80,78,71,54]
   )
)
#grafico
fig = plt.figure(figsize=(13.33,7.5), dpi=96)
ax1 = fig.add_subplot(1,2,1)
ax1.plot(df.Año, df.Susc, label="SCM")
ax1.plot(df.Año, df.tot, label="TOTAL TIC")

ax1.tick_params(axis='x', rotation=75)
ax1.set_xticklabels(df.Año, fontsize=20)
ax1.get_yaxis().set_visible(False)
ax1.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df.Susc):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)
for i, value in enumerate(df.tot):
    ax1.text(i, value, str(value), ha='center', va='bottom', fontsize=22)

ax2 = fig.add_subplot(1,2,2)
df = pd.DataFrame(
   dict(
      Año=["2014","2015","2016","2017","2018","2019","2020","2021","2022"],
      Susc=[58,55,53,51,48,46,46,48,50]
   )
)
ax2.bar(df.Año, df.Susc)
ax2.tick_params(axis='x', rotation=75)
ax2.set_xticklabels(df.Año, fontsize=20)
ax2.get_yaxis().set_visible(False)
ax2.set(frame_on=False)
#agrega etiquetas de valor
for i, value in enumerate(df.Susc):
    ax2.text(i, value, str(value)+"%", ha='center', va='bottom', fontsize=20)

ax1.set_title("EVOLUCION INDICE FACTURACION\n(a precios constantes)", fontweight="bold", fontsize=20)
ax2.set_title("PORCENTAJE SCM SOBRE\nTOTAL MERCADO TIC", fontweight="bold", fontsize=20)
ax1.legend(fontsize=16)

ax2.text(5,-15, "Fuentes: Elaboración propia en base a ENACOM-INDEC", fontsize=12, ha = 'center')

my_suptitle = fig.suptitle("SERIE INGRESOS SCM ARGENTINA", fontsize=24,fontweight="bold", color="black")
plt.tight_layout()

#plt.savefig("EMAE.png", bbox_inches='tight')
#files.download("EMAE.png")
plt.show()
# Out:
# <ipython-input-11-765b81472ba7>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df.Año, fontsize=20)
# <ipython-input-11-765b81472ba7>:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(df.Año, fontsize=20)
